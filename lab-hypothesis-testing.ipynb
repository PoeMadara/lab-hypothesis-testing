# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
display(df)
# Out:
#                           Name    Type 1    Type 2   HP  Attack  Defense  \
# 0                    Bulbasaur     Grass    Poison   45      49       49
# 1                      Ivysaur     Grass    Poison   60      62       63
# 2                     Venusaur     Grass    Poison   80      82       83
# 3                Mega Venusaur     Grass    Poison   80     100      123
# 4                   Charmander      Fire       NaN   39      52       43
# 5                   Charmeleon      Fire       NaN   58      64       58
# 6                    Charizard      Fire    Flying   78      84       78
# 7             Mega Charizard X      Fire    Dragon   78     130      111
# 8             Mega Charizard Y      Fire    Flying   78     104       78
# 9                     Squirtle     Water       NaN   44      48       65
# 10                   Wartortle     Water       NaN   59      63       80
# 11                   Blastoise     Water       NaN   79      83      100
# 12              Mega Blastoise     Water       NaN   79     103      120
# 13                    Caterpie       Bug       NaN   45      30       35
# 14                     Metapod       Bug       NaN   50      20       55
# 15                  Butterfree       Bug    Flying   60      45       50
# 16                      Weedle       Bug    Poison   40      35       30
# 17                      Kakuna       Bug    Poison   45      25       50
# 18                    Beedrill       Bug    Poison   65      90       40
# 19               Mega Beedrill       Bug    Poison   65     150       40
# 20                      Pidgey    Normal    Flying   40      45       40
# 21                   Pidgeotto    Normal    Flying   63      60       55
# 22                     Pidgeot    Normal    Flying   83      80       75
# 23                Mega Pidgeot    Normal    Flying   83      80       80
# 24                     Rattata    Normal       NaN   30      56       35
# 25                    Raticate    Normal       NaN   55      81       60
# 26                     Spearow    Normal    Flying   40      60       30
# 27                      Fearow    Normal    Flying   65      90       65
# 28                       Ekans    Poison       NaN   35      60       44
# 29                       Arbok    Poison       NaN   60      85       69
# 30                     Pikachu  Electric       NaN   35      55       40
# 31                      Raichu  Electric       NaN   60      90       55
# 32                   Sandshrew    Ground       NaN   50      75       85
# 33                   Sandslash    Ground       NaN   75     100      110
# 34                    Nidoran♀    Poison       NaN   55      47       52
# 35                    Nidorina    Poison       NaN   70      62       67
# 36                   Nidoqueen    Poison    Ground   90      92       87
# 37                    Nidoran♂    Poison       NaN   46      57       40
# 38                    Nidorino    Poison       NaN   61      72       57
# 39                    Nidoking    Poison    Ground   81     102       77
# 40                    Clefairy     Fairy       NaN   70      45       48
# 41                    Clefable     Fairy       NaN   95      70       73
# 42                      Vulpix      Fire       NaN   38      41       40
# 43                   Ninetales      Fire       NaN   73      76       75
# 44                  Jigglypuff    Normal     Fairy  115      45       20
# 45                  Wigglytuff    Normal     Fairy  140      70       45
# 46                       Zubat    Poison    Flying   40      45       35
# 47                      Golbat    Poison    Flying   75      80       70
# 48                      Oddish     Grass    Poison   45      50       55
# 49                       Gloom     Grass    Poison   60      65       70
# 50                   Vileplume     Grass    Poison   75      80       85
# 51                       Paras       Bug     Grass   35      70       55
# 52                    Parasect       Bug     Grass   60      95       80
# 53                     Venonat       Bug    Poison   60      55       50
# 54                    Venomoth       Bug    Poison   70      65       60
# 55                     Diglett    Ground       NaN   10      55       25
# 56                     Dugtrio    Ground       NaN   35      80       50
# 57                      Meowth    Normal       NaN   40      45       35
# 58                     Persian    Normal       NaN   65      70       60
# 59                     Psyduck     Water       NaN   50      52       48
# 60                     Golduck     Water       NaN   80      82       78
# 61                      Mankey  Fighting       NaN   40      80       35
# 62                         NaN  Fighting       NaN   65     105       60
# 63                   Growlithe      Fire       NaN   55      70       45
# 64                    Arcanine      Fire       NaN   90     110       80
# 65                     Poliwag     Water       NaN   40      50       40
# 66                   Poliwhirl     Water       NaN   65      65       65
# 67                   Poliwrath     Water  Fighting   90      95       95
# 68                        Abra   Psychic       NaN   25      20       15
# 69                     Kadabra   Psychic       NaN   40      35       30
# 70                    Alakazam   Psychic       NaN   55      50       45
# 71               Mega Alakazam   Psychic       NaN   55      50       65
# 72                      Machop  Fighting       NaN   70      80       50
# 73                     Machoke  Fighting       NaN   80     100       70
# 74                     Machamp  Fighting       NaN   90     130       80
# 75                  Bellsprout     Grass    Poison   50      75       35
# 76                  Weepinbell     Grass    Poison   65      90       50
# 77                  Victreebel     Grass    Poison   80     105       65
# 78                   Tentacool     Water    Poison   40      40       35
# 79                  Tentacruel     Water    Poison   80      70       65
# 80                     Geodude      Rock    Ground   40      80      100
# 81                    Graveler      Rock    Ground   55      95      115
# 82                       Golem      Rock    Ground   80     120      130
# 83                      Ponyta      Fire       NaN   50      85       55
# 84                    Rapidash      Fire       NaN   65     100       70
# 85                    Slowpoke     Water   Psychic   90      65       65
# 86                     Slowbro     Water   Psychic   95      75      110
# 87                Mega Slowbro     Water   Psychic   95      75      180
# 88                   Magnemite  Electric     Steel   25      35       70
# 89                    Magneton  Electric     Steel   50      60       95
# 90                  Farfetch'd    Normal    Flying   52      65       55
# 91                       Doduo    Normal    Flying   35      85       45
# 92                      Dodrio    Normal    Flying   60     110       70
# 93                        Seel     Water       NaN   65      45       55
# 94                     Dewgong     Water       Ice   90      70       80
# 95                      Grimer    Poison       NaN   80      80       50
# 96                         Muk    Poison       NaN  105     105       75
# 97                    Shellder     Water       NaN   30      65      100
# 98                    Cloyster     Water       Ice   50      95      180
# 99                      Gastly     Ghost    Poison   30      35       30
# 100                    Haunter     Ghost    Poison   45      50       45
# 101                     Gengar     Ghost    Poison   60      65       60
# 102                Mega Gengar     Ghost    Poison   60      65       80
# 103                       Onix      Rock    Ground   35      45      160
# 104                    Drowzee   Psychic       NaN   60      48       45
# 105                      Hypno   Psychic       NaN   85      73       70
# 106                     Krabby     Water       NaN   30     105       90
# 107                    Kingler     Water       NaN   55     130      115
# 108                    Voltorb  Electric       NaN   40      30       50
# 109                  Electrode  Electric       NaN   60      50       70
# 110                  Exeggcute     Grass   Psychic   60      40       80
# 111                  Exeggutor     Grass   Psychic   95      95       85
# 112                     Cubone    Ground       NaN   50      50       95
# 113                    Marowak    Ground       NaN   60      80      110
# 114                  Hitmonlee  Fighting       NaN   50     120       53
# 115                 Hitmonchan  Fighting       NaN   50     105       79
# 116                  Lickitung    Normal       NaN   90      55       75
# 117                    Koffing    Poison       NaN   40      65       95
# 118                    Weezing    Poison       NaN   65      90      120
# 119                    Rhyhorn    Ground      Rock   80      85       95
# 120                     Rhydon    Ground      Rock  105     130      120
# 121                    Chansey    Normal       NaN  250       5        5
# 122                    Tangela     Grass       NaN   65      55      115
# 123                 Kangaskhan    Normal       NaN  105      95       80
# 124            Mega Kangaskhan    Normal       NaN  105     125      100
# 125                     Horsea     Water       NaN   30      40       70
# 126                     Seadra     Water       NaN   55      65       95
# 127                    Goldeen     Water       NaN   45      67       60
# 128                    Seaking     Water       NaN   80      92       65
# 129                     Staryu     Water       NaN   30      45       55
# 130                    Starmie     Water   Psychic   60      75       85
# 131                   Mr. Mime   Psychic     Fairy   40      45       65
# 132                    Scyther       Bug    Flying   70     110       80
# 133                       Jynx       Ice   Psychic   65      50       35
# 134                 Electabuzz  Electric       NaN   65      83       57
# 135                     Magmar      Fire       NaN   65      95       57
# 136                     Pinsir       Bug       NaN   65     125      100
# 137                Mega Pinsir       Bug    Flying   65     155      120
# 138                     Tauros    Normal       NaN   75     100       95
# 139                   Magikarp     Water       NaN   20      10       55
# 140                   Gyarados     Water    Flying   95     125       79
# 141              Mega Gyarados     Water      Dark   95     155      109
# 142                     Lapras     Water       Ice  130      85       80
# 143                      Ditto    Normal       NaN   48      48       48
# 144                      Eevee    Normal       NaN   55      55       50
# 145                   Vaporeon     Water       NaN  130      65       60
# 146                    Jolteon  Electric       NaN   65      65       60
# 147                    Flareon      Fire       NaN   65     130       60
# 148                    Porygon    Normal       NaN   65      60       70
# 149                    Omanyte      Rock     Water   35      40      100
# 150                    Omastar      Rock     Water   70      60      125
# 151                     Kabuto      Rock     Water   30      80       90
# 152                   Kabutops      Rock     Water   60     115      105
# 153                 Aerodactyl      Rock    Flying   80     105       65
# 154            Mega Aerodactyl      Rock    Flying   80     135       85
# 155                    Snorlax    Normal       NaN  160     110       65
# 156                   Articuno       Ice    Flying   90      85      100
# 157                     Zapdos  Electric    Flying   90      90       85
# 158                    Moltres      Fire    Flying   90     100       90
# 159                    Dratini    Dragon       NaN   41      64       45
# 160                  Dragonair    Dragon       NaN   61      84       65
# 161                  Dragonite    Dragon    Flying   91     134       95
# 162                     Mewtwo   Psychic       NaN  106     110       90
# 163              Mega Mewtwo X   Psychic  Fighting  106     190      100
# 164              Mega Mewtwo Y   Psychic       NaN  106     150       70
# 165                        Mew   Psychic       NaN  100     100      100
# 166                  Chikorita     Grass       NaN   45      49       65
# 167                    Bayleef     Grass       NaN   60      62       80
# 168                   Meganium     Grass       NaN   80      82      100
# 169                  Cyndaquil      Fire       NaN   39      52       43
# 170                    Quilava      Fire       NaN   58      64       58
# 171                 Typhlosion      Fire       NaN   78      84       78
# 172                   Totodile     Water       NaN   50      65       64
# 173                   Croconaw     Water       NaN   65      80       80
# 174                 Feraligatr     Water       NaN   85     105      100
# 175                    Sentret    Normal       NaN   35      46       34
# 176                     Furret    Normal       NaN   85      76       64
# 177                   Hoothoot    Normal    Flying   60      30       30
# 178                    Noctowl    Normal    Flying  100      50       50
# 179                     Ledyba       Bug    Flying   40      20       30
# 180                     Ledian       Bug    Flying   55      35       50
# 181                   Spinarak       Bug    Poison   40      60       40
# 182                    Ariados       Bug    Poison   70      90       70
# 183                     Crobat    Poison    Flying   85      90       80
# 184                   Chinchou     Water  Electric   75      38       38
# 185                    Lanturn     Water  Electric  125      58       58
# 186                      Pichu  Electric       NaN   20      40       15
# 187                     Cleffa     Fairy       NaN   50      25       28
# 188                  Igglybuff    Normal     Fairy   90      30       15
# 189                     Togepi     Fairy       NaN   35      20       65
# 190                    Togetic     Fairy    Flying   55      40       85
# 191                       Natu   Psychic    Flying   40      50       45
# 192                       Xatu   Psychic    Flying   65      75       70
# 193                     Mareep  Electric       NaN   55      40       40
# 194                    Flaaffy  Electric       NaN   70      55       55
# 195                   Ampharos  Electric       NaN   90      75       85
# 196              Mega Ampharos  Electric    Dragon   90      95      105
# 197                  Bellossom     Grass       NaN   75      80       95
# 198                     Marill     Water     Fairy   70      20       50
# 199                  Azumarill     Water     Fairy  100      50       80
# 200                  Sudowoodo      Rock       NaN   70     100      115
# 201                   Politoed     Water       NaN   90      75       75
# 202                     Hoppip     Grass    Flying   35      35       40
# 203                   Skiploom     Grass    Flying   55      45       50
# 204                   Jumpluff     Grass    Flying   75      55       70
# 205                      Aipom    Normal       NaN   55      70       55
# 206                    Sunkern     Grass       NaN   30      30       30
# 207                   Sunflora     Grass       NaN   75      75       55
# 208                      Yanma       Bug    Flying   65      65       45
# 209                     Wooper     Water    Ground   55      45       45
# 210                   Quagsire     Water    Ground   95      85       85
# 211                     Espeon   Psychic       NaN   65      65       60
# 212                    Umbreon      Dark       NaN   95      65      110
# 213                    Murkrow      Dark    Flying   60      85       42
# 214                   Slowking     Water   Psychic   95      75       80
# 215                 Misdreavus     Ghost       NaN   60      60       60
# 216                      Unown   Psychic       NaN   48      72       48
# 217                  Wobbuffet   Psychic       NaN  190      33       58
# 218                  Girafarig    Normal   Psychic   70      80       65
# 219                     Pineco       Bug       NaN   50      65       90
# 220                 Forretress       Bug     Steel   75      90      140
# 221                  Dunsparce    Normal       NaN  100      70       70
# 222                     Gligar    Ground    Flying   65      75      105
# 223                    Steelix     Steel    Ground   75      85      200
# 224               Mega Steelix     Steel    Ground   75     125      230
# 225                   Snubbull     Fairy       NaN   60      80       50
# 226                   Granbull     Fairy       NaN   90     120       75
# 227                   Qwilfish     Water    Poison   65      95       75
# 228                     Scizor       Bug     Steel   70     130      100
# 229                Mega Scizor       Bug     Steel   70     150      140
# 230                    Shuckle       Bug      Rock   20      10      230
# 231                  Heracross       Bug  Fighting   80     125       75
# 232             Mega Heracross       Bug  Fighting   80     185      115
# 233                    Sneasel      Dark       Ice   55      95       55
# 234                  Teddiursa    Normal       NaN   60      80       50
# 235                   Ursaring    Normal       NaN   90     130       75
# 236                     Slugma      Fire       NaN   40      40       40
# 237                   Magcargo      Fire      Rock   50      50      120
# 238                     Swinub       Ice    Ground   50      50       40
# 239                  Piloswine       Ice    Ground  100     100       80
# 240                    Corsola     Water      Rock   55      55       85
# 241                   Remoraid     Water       NaN   35      65       35
# 242                  Octillery     Water       NaN   75     105       75
# 243                   Delibird       Ice    Flying   45      55       45
# 244                    Mantine     Water    Flying   65      40       70
# 245                   Skarmory     Steel    Flying   65      80      140
# 246                   Houndour      Dark      Fire   45      60       30
# 247                   Houndoom      Dark      Fire   75      90       50
# 248              Mega Houndoom      Dark      Fire   75      90       90
# 249                    Kingdra     Water    Dragon   75      95       95
# 250                     Phanpy    Ground       NaN   90      60       60
# 251                    Donphan    Ground       NaN   90     120      120
# 252                   Porygon2    Normal       NaN   85      80       90
# 253                   Stantler    Normal       NaN   73      95       62
# 254                   Smeargle    Normal       NaN   55      20       35
# 255                    Tyrogue  Fighting       NaN   35      35       35
# 256                  Hitmontop  Fighting       NaN   50      95       95
# 257                   Smoochum       Ice   Psychic   45      30       15
# 258                     Elekid  Electric       NaN   45      63       37
# 259                      Magby      Fire       NaN   45      75       37
# 260                    Miltank    Normal       NaN   95      80      105
# 261                    Blissey    Normal       NaN  255      10       10
# 262                     Raikou  Electric       NaN   90      85       75
# 263                      Entei      Fire       NaN  115     115       85
# 264                    Suicune     Water       NaN  100      75      115
# 265                   Larvitar      Rock    Ground   50      64       50
# 266                    Pupitar      Rock    Ground   70      84       70
# 267                  Tyranitar      Rock      Dark  100     134      110
# 268             Mega Tyranitar      Rock      Dark  100     164      150
# 269                      Lugia   Psychic    Flying  106      90      130
# 270                      Ho-oh      Fire    Flying  106     130       90
# 271                     Celebi   Psychic     Grass  100     100      100
# 272                    Treecko     Grass       NaN   40      45       35
# 273                    Grovyle     Grass       NaN   50      65       45
# 274                   Sceptile     Grass       NaN   70      85       65
# 275              Mega Sceptile     Grass    Dragon   70     110       75
# 276                    Torchic      Fire       NaN   45      60       40
# 277                  Combusken      Fire  Fighting   60      85       60
# 278                   Blaziken      Fire  Fighting   80     120       70
# 279              Mega Blaziken      Fire  Fighting   80     160       80
# 280                     Mudkip     Water       NaN   50      70       50
# 281                  Marshtomp     Water    Ground   70      85       70
# 282                   Swampert     Water    Ground  100     110       90
# 283              Mega Swampert     Water    Ground  100     150      110
# 284                  Poochyena      Dark       NaN   35      55       35
# 285                  Mightyena      Dark       NaN   70      90       70
# 286                  Zigzagoon    Normal       NaN   38      30       41
# 287                    Linoone    Normal       NaN   78      70       61
# 288                    Wurmple       Bug       NaN   45      45       35
# 289                    Silcoon       Bug       NaN   50      35       55
# 290                  Beautifly       Bug    Flying   60      70       50
# 291                    Cascoon       Bug       NaN   50      35       55
# 292                     Dustox       Bug    Poison   60      50       70
# 293                      Lotad     Water     Grass   40      30       30
# 294                     Lombre     Water     Grass   60      50       50
# 295                   Ludicolo     Water     Grass   80      70       70
# 296                     Seedot     Grass       NaN   40      40       50
# 297                    Nuzleaf     Grass      Dark   70      70       40
# 298                    Shiftry     Grass      Dark   90     100       60
# 299                    Taillow    Normal    Flying   40      55       30
# 300                    Swellow    Normal    Flying   60      85       60
# 301                    Wingull     Water    Flying   40      30       30
# 302                   Pelipper     Water    Flying   60      50      100
# 303                      Ralts   Psychic     Fairy   28      25       25
# 304                     Kirlia   Psychic     Fairy   38      35       35
# 305                  Gardevoir   Psychic     Fairy   68      65       65
# 306             Mega Gardevoir   Psychic     Fairy   68      85       65
# 307                    Surskit       Bug     Water   40      30       32
# 308                 Masquerain       Bug    Flying   70      60       62
# 309                  Shroomish     Grass       NaN   60      40       60
# 310                    Breloom     Grass  Fighting   60     130       80
# 311                    Slakoth    Normal       NaN   60      60       60
# 312                   Vigoroth    Normal       NaN   80      80       80
# 313                    Slaking    Normal       NaN  150     160      100
# 314                    Nincada       Bug    Ground   31      45       90
# 315                    Ninjask       Bug    Flying   61      90       45
# 316                   Shedinja       Bug     Ghost    1      90       45
# 317                    Whismur    Normal       NaN   64      51       23
# 318                    Loudred    Normal       NaN   84      71       43
# 319                    Exploud    Normal       NaN  104      91       63
# 320                   Makuhita  Fighting       NaN   72      60       30
# 321                   Hariyama  Fighting       NaN  144     120       60
# 322                    Azurill    Normal     Fairy   50      20       40
# 323                   Nosepass      Rock       NaN   30      45      135
# 324                     Skitty    Normal       NaN   50      45       45
# 325                   Delcatty    Normal       NaN   70      65       65
# 326                    Sableye      Dark     Ghost   50      75       75
# 327               Mega Sableye      Dark     Ghost   50      85      125
# 328                     Mawile     Steel     Fairy   50      85       85
# 329                Mega Mawile     Steel     Fairy   50     105      125
# 330                       Aron     Steel      Rock   50      70      100
# 331                     Lairon     Steel      Rock   60      90      140
# 332                     Aggron     Steel      Rock   70     110      180
# 333                Mega Aggron     Steel       NaN   70     140      230
# 334                   Meditite  Fighting   Psychic   30      40       55
# 335                   Medicham  Fighting   Psychic   60      60       75
# 336              Mega Medicham  Fighting   Psychic   60     100       85
# 337                  Electrike  Electric       NaN   40      45       40
# 338                  Manectric  Electric       NaN   70      75       60
# 339             Mega Manectric  Electric       NaN   70      75       80
# 340                     Plusle  Electric       NaN   60      50       40
# 341                      Minun  Electric       NaN   60      40       50
# 342                    Volbeat       Bug       NaN   65      73       55
# 343                   Illumise       Bug       NaN   65      47       55
# 344                    Roselia     Grass    Poison   50      60       45
# 345                     Gulpin    Poison       NaN   70      43       53
# 346                     Swalot    Poison       NaN  100      73       83
# 347                   Carvanha     Water      Dark   45      90       20
# 348                   Sharpedo     Water      Dark   70     120       40
# 349              Mega Sharpedo     Water      Dark   70     140       70
# 350                    Wailmer     Water       NaN  130      70       35
# 351                    Wailord     Water       NaN  170      90       45
# 352                      Numel      Fire    Ground   60      60       40
# 353                   Camerupt      Fire    Ground   70     100       70
# 354              Mega Camerupt      Fire    Ground   70     120      100
# 355                    Torkoal      Fire       NaN   70      85      140
# 356                     Spoink   Psychic       NaN   60      25       35
# 357                    Grumpig   Psychic       NaN   80      45       65
# 358                     Spinda    Normal       NaN   60      60       60
# 359                   Trapinch    Ground       NaN   45     100       45
# 360                    Vibrava    Ground    Dragon   50      70       50
# 361                     Flygon    Ground    Dragon   80     100       80
# 362                     Cacnea     Grass       NaN   50      85       40
# 363                   Cacturne     Grass      Dark   70     115       60
# 364                     Swablu    Normal    Flying   45      40       60
# 365                    Altaria    Dragon    Flying   75      70       90
# 366               Mega Altaria    Dragon     Fairy   75     110      110
# 367                   Zangoose    Normal       NaN   73     115       60
# 368                    Seviper    Poison       NaN   73     100       60
# 369                   Lunatone      Rock   Psychic   70      55       65
# 370                    Solrock      Rock   Psychic   70      95       85
# 371                   Barboach     Water    Ground   50      48       43
# 372                   Whiscash     Water    Ground  110      78       73
# 373                   Corphish     Water       NaN   43      80       65
# 374                  Crawdaunt     Water      Dark   63     120       85
# 375                     Baltoy    Ground   Psychic   40      40       55
# 376                    Claydol    Ground   Psychic   60      70      105
# 377                     Lileep      Rock     Grass   66      41       77
# 378                    Cradily      Rock     Grass   86      81       97
# 379                    Anorith      Rock       Bug   45      95       50
# 380                    Armaldo      Rock       Bug   75     125      100
# 381                     Feebas     Water       NaN   20      15       20
# 382                    Milotic     Water       NaN   95      60       79
# 383                   Castform    Normal       NaN   70      70       70
# 384                    Kecleon    Normal       NaN   60      90       70
# 385                    Shuppet     Ghost       NaN   44      75       35
# 386                    Banette     Ghost       NaN   64     115       65
# 387               Mega Banette     Ghost       NaN   64     165       75
# 388                    Duskull     Ghost       NaN   20      40       90
# 389                   Dusclops     Ghost       NaN   40      70      130
# 390                    Tropius     Grass    Flying   99      68       83
# 391                   Chimecho   Psychic       NaN   65      50       70
# 392                      Absol      Dark       NaN   65     130       60
# 393                 Mega Absol      Dark       NaN   65     150       60
# 394                     Wynaut   Psychic       NaN   95      23       48
# 395                    Snorunt       Ice       NaN   50      50       50
# 396                     Glalie       Ice       NaN   80      80       80
# 397                Mega Glalie       Ice       NaN   80     120       80
# 398                     Spheal       Ice     Water   70      40       50
# 399                     Sealeo       Ice     Water   90      60       70
# 400                    Walrein       Ice     Water  110      80       90
# 401                   Clamperl     Water       NaN   35      64       85
# 402                    Huntail     Water       NaN   55     104      105
# 403                   Gorebyss     Water       NaN   55      84      105
# 404                  Relicanth     Water      Rock  100      90      130
# 405                    Luvdisc     Water       NaN   43      30       55
# 406                      Bagon    Dragon       NaN   45      75       60
# 407                    Shelgon    Dragon       NaN   65      95      100
# 408                  Salamence    Dragon    Flying   95     135       80
# 409             Mega Salamence    Dragon    Flying   95     145      130
# 410                     Beldum     Steel   Psychic   40      55       80
# 411                     Metang     Steel   Psychic   60      75      100
# 412                  Metagross     Steel   Psychic   80     135      130
# 413             Mega Metagross     Steel   Psychic   80     145      150
# 414                   Regirock      Rock       NaN   80     100      200
# 415                     Regice       Ice       NaN   80      50      100
# 416                  Registeel     Steel       NaN   80      75      150
# 417                     Latias    Dragon   Psychic   80      80       90
# 418                Mega Latias    Dragon   Psychic   80     100      120
# 419                     Latios    Dragon   Psychic   80      90       80
# 420                Mega Latios    Dragon   Psychic   80     130      100
# 421                     Kyogre     Water       NaN  100     100       90
# 422              Primal Kyogre     Water       NaN  100     150       90
# 423                    Groudon    Ground       NaN  100     150      140
# 424             Primal Groudon    Ground      Fire  100     180      160
# 425                   Rayquaza    Dragon    Flying  105     150       90
# 426              Mega Rayquaza    Dragon    Flying  105     180      100
# 427                    Jirachi     Steel   Psychic  100     100      100
# 428        Deoxys Normal Forme   Psychic       NaN   50     150       50
# 429         DeoxysAttack Forme   Psychic       NaN   50     180       20
# 430       Deoxys Defense Forme   Psychic       NaN   50      70      160
# 431         Deoxys Speed Forme   Psychic       NaN   50      95       90
# 432                    Turtwig     Grass       NaN   55      68       64
# 433                     Grotle     Grass       NaN   75      89       85
# 434                   Torterra     Grass    Ground   95     109      105
# 435                   Chimchar      Fire       NaN   44      58       44
# 436                   Monferno      Fire  Fighting   64      78       52
# 437                  Infernape      Fire  Fighting   76     104       71
# 438                     Piplup     Water       NaN   53      51       53
# 439                   Prinplup     Water       NaN   64      66       68
# 440                   Empoleon     Water     Steel   84      86       88
# 441                     Starly    Normal    Flying   40      55       30
# 442                   Staravia    Normal    Flying   55      75       50
# 443                  Staraptor    Normal    Flying   85     120       70
# 444                     Bidoof    Normal       NaN   59      45       40
# 445                    Bibarel    Normal     Water   79      85       60
# 446                  Kricketot       Bug       NaN   37      25       41
# 447                 Kricketune       Bug       NaN   77      85       51
# 448                      Shinx  Electric       NaN   45      65       34
# 449                      Luxio  Electric       NaN   60      85       49
# 450                     Luxray  Electric       NaN   80     120       79
# 451                      Budew     Grass    Poison   40      30       35
# 452                   Roserade     Grass    Poison   60      70       65
# 453                   Cranidos      Rock       NaN   67     125       40
# 454                  Rampardos      Rock       NaN   97     165       60
# 455                   Shieldon      Rock     Steel   30      42      118
# 456                  Bastiodon      Rock     Steel   60      52      168
# 457                      Burmy       Bug       NaN   40      29       45
# 458       Wormadam Plant Cloak       Bug     Grass   60      59       85
# 459       Wormadam Sandy Cloak       Bug    Ground   60      79      105
# 460       Wormadam Trash Cloak       Bug     Steel   60      69       95
# 461                     Mothim       Bug    Flying   70      94       50
# 462                     Combee       Bug    Flying   30      30       42
# 463                  Vespiquen       Bug    Flying   70      80      102
# 464                  Pachirisu  Electric       NaN   60      45       70
# 465                     Buizel     Water       NaN   55      65       35
# 466                   Floatzel     Water       NaN   85     105       55
# 467                    Cherubi     Grass       NaN   45      35       45
# 468                    Cherrim     Grass       NaN   70      60       70
# 469                    Shellos     Water       NaN   76      48       48
# 470                  Gastrodon     Water    Ground  111      83       68
# 471                    Ambipom    Normal       NaN   75     100       66
# 472                   Drifloon     Ghost    Flying   90      50       34
# 473                   Drifblim     Ghost    Flying  150      80       44
# 474                    Buneary    Normal       NaN   55      66       44
# 475                    Lopunny    Normal       NaN   65      76       84
# 476               Mega Lopunny    Normal  Fighting   65     136       94
# 477                  Mismagius     Ghost       NaN   60      60       60
# 478                  Honchkrow      Dark    Flying  100     125       52
# 479                    Glameow    Normal       NaN   49      55       42
# 480                    Purugly    Normal       NaN   71      82       64
# 481                  Chingling   Psychic       NaN   45      30       50
# 482                     Stunky    Poison      Dark   63      63       47
# 483                   Skuntank    Poison      Dark  103      93       67
# 484                    Bronzor     Steel   Psychic   57      24       86
# 485                   Bronzong     Steel   Psychic   67      89      116
# 486                     Bonsly      Rock       NaN   50      80       95
# 487                   Mime Jr.   Psychic     Fairy   20      25       45
# 488                    Happiny    Normal       NaN  100       5        5
# 489                     Chatot    Normal    Flying   76      65       45
# 490                  Spiritomb     Ghost      Dark   50      92      108
# 491                      Gible    Dragon    Ground   58      70       45
# 492                     Gabite    Dragon    Ground   68      90       65
# 493                   Garchomp    Dragon    Ground  108     130       95
# 494              Mega Garchomp    Dragon    Ground  108     170      115
# 495                   Munchlax    Normal       NaN  135      85       40
# 496                      Riolu  Fighting       NaN   40      70       40
# 497                    Lucario  Fighting     Steel   70     110       70
# 498               Mega Lucario  Fighting     Steel   70     145       88
# 499                 Hippopotas    Ground       NaN   68      72       78
# 500                  Hippowdon    Ground       NaN  108     112      118
# 501                    Skorupi    Poison       Bug   40      50       90
# 502                    Drapion    Poison      Dark   70      90      110
# 503                   Croagunk    Poison  Fighting   48      61       40
# 504                  Toxicroak    Poison  Fighting   83     106       65
# 505                  Carnivine     Grass       NaN   74     100       72
# 506                    Finneon     Water       NaN   49      49       56
# 507                   Lumineon     Water       NaN   69      69       76
# 508                    Mantyke     Water    Flying   45      20       50
# 509                     Snover     Grass       Ice   60      62       50
# 510                  Abomasnow     Grass       Ice   90      92       75
# 511             Mega Abomasnow     Grass       Ice   90     132      105
# 512                    Weavile      Dark       Ice   70     120       65
# 513                  Magnezone  Electric     Steel   70      70      115
# 514                 Lickilicky    Normal       NaN  110      85       95
# 515                  Rhyperior    Ground      Rock  115     140      130
# 516                  Tangrowth     Grass       NaN  100     100      125
# 517                 Electivire  Electric       NaN   75     123       67
# 518                  Magmortar      Fire       NaN   75      95       67
# 519                   Togekiss     Fairy    Flying   85      50       95
# 520                    Yanmega       Bug    Flying   86      76       86
# 521                    Leafeon     Grass       NaN   65     110      130
# 522                    Glaceon       Ice       NaN   65      60      110
# 523                    Gliscor    Ground    Flying   75      95      125
# 524                  Mamoswine       Ice    Ground  110     130       80
# 525                  Porygon-Z    Normal       NaN   85      80       70
# 526                    Gallade   Psychic  Fighting   68     125       65
# 527               Mega Gallade   Psychic  Fighting   68     165       95
# 528                  Probopass      Rock     Steel   60      55      145
# 529                   Dusknoir     Ghost       NaN   45     100      135
# 530                   Froslass       Ice     Ghost   70      80       70
# 531                      Rotom  Electric     Ghost   50      50       77
# 532                 Heat Rotom  Electric      Fire   50      65      107
# 533                 Wash Rotom  Electric     Water   50      65      107
# 534                Frost Rotom  Electric       Ice   50      65      107
# 535                  Fan Rotom  Electric    Flying   50      65      107
# 536                  Mow Rotom  Electric     Grass   50      65      107
# 537                       Uxie   Psychic       NaN   75      75      130
# 538                    Mesprit   Psychic       NaN   80     105      105
# 539                      Azelf   Psychic       NaN   75     125       70
# 540                     Dialga     Steel    Dragon  100     120      120
# 541                     Palkia     Water    Dragon   90     120      100
# 542                    Heatran      Fire     Steel   91      90      106
# 543                  Regigigas    Normal       NaN  110     160      110
# 544     Giratina Altered Forme     Ghost    Dragon  150     100      120
# 545      Giratina Origin Forme     Ghost    Dragon  150     120      100
# 546                  Cresselia   Psychic       NaN  120      70      120
# 547                     Phione     Water       NaN   80      80       80
# 548                    Manaphy     Water       NaN  100     100      100
# 549                    Darkrai      Dark       NaN   70      90       90
# 550         Shaymin Land Forme     Grass       NaN  100     100      100
# 551          Shaymin Sky Forme     Grass    Flying  100     103       75
# 552                     Arceus    Normal       NaN  120     120      120
# 553                    Victini   Psychic      Fire  100     100      100
# 554                      Snivy     Grass       NaN   45      45       55
# 555                    Servine     Grass       NaN   60      60       75
# 556                  Serperior     Grass       NaN   75      75       95
# 557                      Tepig      Fire       NaN   65      63       45
# 558                    Pignite      Fire  Fighting   90      93       55
# 559                     Emboar      Fire  Fighting  110     123       65
# 560                   Oshawott     Water       NaN   55      55       45
# 561                     Dewott     Water       NaN   75      75       60
# 562                   Samurott     Water       NaN   95     100       85
# 563                     Patrat    Normal       NaN   45      55       39
# 564                    Watchog    Normal       NaN   60      85       69
# 565                   Lillipup    Normal       NaN   45      60       45
# 566                    Herdier    Normal       NaN   65      80       65
# 567                  Stoutland    Normal       NaN   85     110       90
# 568                   Purrloin      Dark       NaN   41      50       37
# 569                    Liepard      Dark       NaN   64      88       50
# 570                    Pansage     Grass       NaN   50      53       48
# 571                   Simisage     Grass       NaN   75      98       63
# 572                    Pansear      Fire       NaN   50      53       48
# 573                   Simisear      Fire       NaN   75      98       63
# 574                    Panpour     Water       NaN   50      53       48
# 575                   Simipour     Water       NaN   75      98       63
# 576                      Munna   Psychic       NaN   76      25       45
# 577                   Musharna   Psychic       NaN  116      55       85
# 578                     Pidove    Normal    Flying   50      55       50
# 579                  Tranquill    Normal    Flying   62      77       62
# 580                   Unfezant    Normal    Flying   80     115       80
# 581                    Blitzle  Electric       NaN   45      60       32
# 582                  Zebstrika  Electric       NaN   75     100       63
# 583                 Roggenrola      Rock       NaN   55      75       85
# 584                    Boldore      Rock       NaN   70     105      105
# 585                   Gigalith      Rock       NaN   85     135      130
# 586                     Woobat   Psychic    Flying   55      45       43
# 587                    Swoobat   Psychic    Flying   67      57       55
# 588                    Drilbur    Ground       NaN   60      85       40
# 589                  Excadrill    Ground     Steel  110     135       60
# 590                     Audino    Normal       NaN  103      60       86
# 591                Mega Audino    Normal     Fairy  103      60      126
# 592                    Timburr  Fighting       NaN   75      80       55
# 593                    Gurdurr  Fighting       NaN   85     105       85
# 594                 Conkeldurr  Fighting       NaN  105     140       95
# 595                    Tympole     Water       NaN   50      50       40
# 596                  Palpitoad     Water    Ground   75      65       55
# 597                 Seismitoad     Water    Ground  105      95       75
# 598                      Throh  Fighting       NaN  120     100       85
# 599                       Sawk  Fighting       NaN   75     125       75
# 600                   Sewaddle       Bug     Grass   45      53       70
# 601                   Swadloon       Bug     Grass   55      63       90
# 602                   Leavanny       Bug     Grass   75     103       80
# 603                   Venipede       Bug    Poison   30      45       59
# 604                 Whirlipede       Bug    Poison   40      55       99
# 605                  Scolipede       Bug    Poison   60     100       89
# 606                   Cottonee     Grass     Fairy   40      27       60
# 607                 Whimsicott     Grass     Fairy   60      67       85
# 608                    Petilil     Grass       NaN   45      35       50
# 609                  Lilligant     Grass       NaN   70      60       75
# 610                   Basculin     Water       NaN   70      92       65
# 611                    Sandile    Ground      Dark   50      72       35
# 612                   Krokorok    Ground      Dark   60      82       45
# 613                 Krookodile    Ground      Dark   95     117       80
# 614                   Darumaka      Fire       NaN   70      90       45
# 615   Darmanitan Standard Mode      Fire       NaN  105     140       55
# 616        Darmanitan Zen Mode      Fire   Psychic  105      30      105
# 617                   Maractus     Grass       NaN   75      86       67
# 618                    Dwebble       Bug      Rock   50      65       85
# 619                    Crustle       Bug      Rock   70      95      125
# 620                    Scraggy      Dark  Fighting   50      75       70
# 621                    Scrafty      Dark  Fighting   65      90      115
# 622                   Sigilyph   Psychic    Flying   72      58       80
# 623                     Yamask     Ghost       NaN   38      30       85
# 624                 Cofagrigus     Ghost       NaN   58      50      145
# 625                   Tirtouga     Water      Rock   54      78      103
# 626                 Carracosta     Water      Rock   74     108      133
# 627                     Archen      Rock    Flying   55     112       45
# 628                   Archeops      Rock    Flying   75     140       65
# 629                   Trubbish    Poison       NaN   50      50       62
# ...
# 504       86       65     85           4      False
# 505       90       72     46           4      False
# 506       49       61     66           4      False
# 507       69       86     91           4      False
# 508       60      120     50           4      False
# 509       62       60     40           4      False
# 510       92       85     60           4      False
# 511      132      105     30           4      False
# 512       45       85    125           4      False
# 513      130       90     60           4      False
# 514       80       95     50           4      False
# 515       55       55     40           4      False
# 516      110       50     50           4      False
# 517       95       85     95           4      False
# 518      125       95     83           4      False
# 519      120      115     80           4      False
# 520      116       56     95           4      False
# 521       60       65     95           4      False
# 522      130       95     65           4      False
# 523       45       75     95           4      False
# 524       70       60     80           4      False
# 525      135       75     90           4      False
# 526       65      115     80           4      False
# 527       65      115    110           4      False
# 528       75      150     40           4      False
# 529       65      135     45           4      False
# 530       80       70    110           4      False
# 531       95       77     91           4      False
# 532      105      107     86           4      False
# 533      105      107     86           4      False
# 534      105      107     86           4      False
# 535      105      107     86           4      False
# 536      105      107     86           4      False
# 537       75      130     95           4       True
# 538      105      105     80           4       True
# 539      125       70    115           4       True
# 540      150      100     90           4       True
# 541      150      120    100           4       True
# 542      130      106     77           4       True
# 543       80      110    100           4       True
# 544      100      120     90           4       True
# 545      120      100     90           4       True
# 546       75      130     85           4      False
# 547       80       80     80           4      False
# 548      100      100    100           4      False
# 549      135       90    125           4       True
# 550      100      100    100           4       True
# 551      120       75    127           4       True
# 552      120      120    120           4       True
# 553      100      100    100           5       True
# 554       45       55     63           5      False
# 555       60       75     83           5      False
# 556       75       95    113           5      False
# 557       45       45     45           5      False
# 558       70       55     55           5      False
# 559      100       65     65           5      False
# 560       63       45     45           5      False
# 561       83       60     60           5      False
# 562      108       70     70           5      False
# 563       35       39     42           5      False
# 564       60       69     77           5      False
# 565       25       45     55           5      False
# 566       35       65     60           5      False
# 567       45       90     80           5      False
# 568       50       37     66           5      False
# 569       88       50    106           5      False
# 570       53       48     64           5      False
# 571       98       63    101           5      False
# 572       53       48     64           5      False
# 573       98       63    101           5      False
# 574       53       48     64           5      False
# 575       98       63    101           5      False
# 576       67       55     24           5      False
# 577      107       95     29           5      False
# 578       36       30     43           5      False
# 579       50       42     65           5      False
# 580       65       55     93           5      False
# 581       50       32     76           5      False
# 582       80       63    116           5      False
# 583       25       25     15           5      False
# 584       50       40     20           5      False
# 585       60       80     25           5      False
# 586       55       43     72           5      False
# 587       77       55    114           5      False
# 588       30       45     68           5      False
# 589       50       65     88           5      False
# 590       60       86     50           5      False
# 591       80      126     50           5      False
# 592       25       35     35           5      False
# 593       40       50     40           5      False
# 594       55       65     45           5      False
# 595       50       40     64           5      False
# 596       65       55     69           5      False
# 597       85       75     74           5      False
# 598       30       85     45           5      False
# 599       30       75     85           5      False
# 600       40       60     42           5      False
# 601       50       80     42           5      False
# 602       70       80     92           5      False
# 603       30       39     57           5      False
# 604       40       79     47           5      False
# 605       55       69    112           5      False
# 606       37       50     66           5      False
# 607       77       75    116           5      False
# 608       70       50     30           5      False
# 609      110       75     90           5      False
# 610       80       55     98           5      False
# 611       35       35     65           5      False
# 612       45       45     74           5      False
# 613       65       70     92           5      False
# 614       15       45     50           5      False
# 615       30       55     95           5      False
# 616      140      105     55           5      False
# 617      106       67     60           5      False
# 618       35       35     55           5      False
# 619       65       75     45           5      False
# 620       35       70     48           5      False
# 621       45      115     58           5      False
# 622      103       80     97           5      False
# 623       55       65     30           5      False
# 624       95      105     30           5      False
# 625       53       45     22           5      False
# 626       83       65     32           5      False
# 627       74       45     70           5      False
# 628      112       65    110           5      False
# 629       40       62     65           5      False
# 630       60       82     75           5      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# 633       40       40     75           5      False
# 634       65       60    115           5      False
# 635       55       65     45           5      False
# 636       75       85     55           5      False
# 637       95      110     65           5      False
# 638      105       50     20           5      False
# 639      125       60     30           5      False
# 640      125       85     30           5      False
# 641       44       50     55           5      False
# 642       87       63     98           5      False
# 643       65       60     44           5      False
# 644       80       75     59           5      False
# 645      110       95     79           5      False
# 646       40       50     75           5      False
# 647       60       70     95           5      False
# 648       75       60    103           5      False
# 649       40       45     60           5      False
# 650       60      105     20           5      False
# 651       55       55     15           5      False
# 652       85       80     30           5      False
# 653       65       85     40           5      False
# 654       85      105     60           5      False
# 655       40       45     65           5      False
# 656       57       50     65           5      False
# 657       97       60    108           5      False
# 658       24       86     10           5      False
# 659       54      116     20           5      False
# 660       45       60     30           5      False
# 661       70       85     50           5      False
# 662       70       85     90           5      False
# 663       45       40     60           5      False
# 664       75       70     40           5      False
# 665      105       80     50           5      False
# 666       85       55     30           5      False
# 667      125       95     40           5      False
# 668       65       55     20           5      False
# 669       95       60     55           5      False
# 670      145       90     80           5      False
# 671       30       40     57           5      False
# 672       40       50     67           5      False
# 673       60       70     97           5      False
# 674       60       40     40           5      False
# 675       70       80     50           5      False
# 676       95      135    105           5      False
# 677       40       65     25           5      False
# 678      100       60    145           5      False
# 679       81       99     32           5      False
# 680       55       50     65           5      False
# 681       95       60    105           5      False
# 682       60       90     48           5      False
# 683       35       50     35           5      False
# 684       55       80     55           5      False
# 685       40       40     60           5      False
# 686       60       70     70           5      False
# 687       40       95     55           5      False
# 688       37       50     60           5      False
# 689       57       75     80           5      False
# 690       45       65     60           5      False
# 691       55       95     80           5      False
# 692      105       66     65           5      False
# 693       48       48    109           5      False
# 694       45       50     38           5      False
# 695       65       70     58           5      False
# 696      125       90     98           5      False
# 697       50       55     60           5      False
# 698      135      105    100           5      False
# 699       90       72    108           5       True
# 700       72       90    108           5       True
# 701       90      129    108           5       True
# 702      125       80    111           5       True
# 703      110       90    121           5       True
# 704      125       80    111           5       True
# 705      145       80    101           5       True
# 706      150      120     90           5       True
# 707      120      100     90           5       True
# 708      115       80    101           5       True
# 709      105       80     91           5       True
# 710      130       90     95           5       True
# 711      120       90     95           5       True
# 712      170      100     95           5       True
# 713      129       90    108           5      False
# 714      129       90    108           5      False
# 715      128      128     90           5      False
# 716       77       77    128           5      False
# 717      120       95     99           5      False
# 718       48       45     38           6      False
# 719       56       58     57           6      False
# 720       74       75     64           6      False
# 721       62       60     60           6      False
# 722       90       70     73           6      False
# 723      114      100    104           6      False
# 724       62       44     71           6      False
# 725       83       56     97           6      False
# 726      103       71    122           6      False
# 727       32       36     57           6      False
# 728       50       77     78           6      False
# 729       40       38     62           6      False
# 730       56       52     84           6      False
# 731       74       69    126           6      False
# 732       27       25     35           6      False
# 733       27       30     29           6      False
# 734       90       50     89           6      False
# 735       73       54     72           6      False
# 736      109       66    106           6      False
# 737       61       79     42           6      False
# 738       75       98     52           6      False
# 739      112      154     75           6      False
# 740       62       57     52           6      False
# 741       97       81     68           6      False
# 742       46       48     43           6      False
# 743       69       71     58           6      False
# 744       65       90    102           6      False
# 745       63       60     68           6      False
# 746       83       81    104           6      False
# 747       83       81    104           6      False
# 748       35       37     28           6      False
# 749       45       49     35           6      False
# 750      150       50     60           6      False
# 751       50      150     60           6      False
# 752       63       65     23           6      False
# 753       99       89     29           6      False
# 754       59       57     49           6      False
# 755       85       75     72           6      False
# 756       37       46     45           6      False
# 757       68       75     73           6      False
# 758       39       56     50           6      False
# 759       54       86     68           6      False
# 760       60       60     30           6      False
# 761       97      123     44           6      False
# 762       58       63     44           6      False
# 763      120       89     59           6      False
# 764       61       43     70           6      False
# 765      109       94    109           6      False
# 766       45       45     48           6      False
# 767       69       59     71           6      False
# 768       67       63     46           6      False
# 769       99       92     58           6      False
# 770      110      130     60           6      False
# 771       74       63    118           6      False
# 772       81       67    101           6      False
# 773       50      150     50           6      False
# 774       55       75     40           6      False
# 775       83      113     60           6      False
# 776      110      150     80           6      False
# 777       80       87     75           6      False
# 778       50       60     38           6      False
# 779       65       82     56           6      False
# 780       44       55     51           6      False
# 781       44       55     56           6      False
# 782       44       55     46           6      False
# 783       44       55     41           6      False
# 784       58       75     84           6      False
# 785       58       75     99           6      False
# 786       58       75     69           6      False
# 787       58       75     54           6      False
# 788       32       35     28           6      False
# 789       44       46     28           6      False
# 790       45       40     55           6      False
# 791       97       80    123           6      False
# 792      131       98     99           6       True
# 793      131       98     99           6       True
# 794       81       95     95           6       True
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %%
#code here

# Load the data
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv'
pokemon_data = pd.read_csv(url)

# Filter Dragon and Grass-type Pokémon
dragon_hp = pokemon_data[pokemon_data['Type 1'] == 'Dragon']['HP']
grass_hp = pokemon_data[pokemon_data['Type 1'] == 'Grass']['HP']

# Hypotheses
# H0: The average HP of Dragon-type Pokémon is equal to the average HP of Grass-type Pokémon
# H1: The average HP of Dragon-type Pokémon is greater than the average HP of Grass-type Pokémon

# Perform the T-Test
t_statistic, p_value = st.ttest_ind(dragon_hp, grass_hp, alternative='greater')

print("Comparison of HP between Dragon-type and Grass-type Pokémon:")
print(f"t-statistic = {t_statistic}, p-value = {p_value}")

# Interpret the p-value
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis: Dragon-type Pokémon have, on average, more HP than Grass-type Pokémon.")
else:
    print("Fail to reject the null hypothesis: There is not enough evidence to claim that Dragon-type Pokémon have more HP than Grass-type Pokémon.")

'''
Interpretation:

The t-statistic of 3.59 indicates that the difference in means between Dragon-type and Grass-type Pokémon is statistically significant.
The p-value of 0.00026 is much lower than the significance level of 0.05 (5%).

Conclusion:

Since the p-value is less than 0.05, we reject the null hypothesis. This supports the alternative hypothesis (H1) that Dragon-type Pokémon have, on average, more HP than Grass-type Pokémon.
Thus, this hypothesis is corroborated by the results
'''
# Out:
# Comparison of HP between Dragon-type and Grass-type Pokémon:
# t-statistic = 3.590444254130357, p-value = 0.0002567969150153481
# Reject the null hypothesis: Dragon-type Pokémon have, on average, more HP than Grass-type Pokémon.
# '\nInterpretation:\n\nThe t-statistic of 3.59 indicates that the difference in means between Dragon-type and Grass-type Pokémon is statistically significant.\nThe p-value of 0.00026 is much lower than the significance level of 0.05 (5%).\n\nConclusion:\n\nSince the p-value is less than 0.05, we reject the null hypothesis. This supports the alternative hypothesis (H1) that Dragon-type Pokémon have, on average, more HP than Grass-type Pokémon.\nThus, this hypothesis is corroborated by the results\n'

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
#code here

# Filter statistics for Legendary and Non-Legendary Pokémon
legendary_stats = pokemon_data[pokemon_data['Legendary'] == True][['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]
non_legendary_stats = pokemon_data[pokemon_data['Legendary'] == False][['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]

# Perform a T-Test for each statistic
results = {}
for stat in legendary_stats.columns:
    t_statistic, p_value = st.ttest_ind(legendary_stats[stat], non_legendary_stats[stat])
    results[stat] = (t_statistic, p_value)

print("\nComparison of stats between Legendary and Non-Legendary Pokémon:")
for stat, (t_statistic, p_value) in results.items():
    print(f"{stat}: t-statistic = {t_statistic}, p-value = {p_value}")

# Interpret the p-values
significant_stats = []
for stat, (t_statistic, p_value) in results.items():
    if p_value < alpha:
        significant_stats.append(stat)

if significant_stats:
    print(f"Reject the null hypothesis for the following stats: {', '.join(significant_stats)}. Legendary Pokémon have different stats compared to Non-Legendary Pokémon.")
else:
    print("Fail to reject the null hypothesis for all stats: There is not enough evidence to claim that Legendary Pokémon have different stats than Non-Legendary Pokémon.")


'''
Interpretation:

All the t-statistics are significantly high, indicating a strong difference in means between Legendary and Non-Legendary Pokémon for each stat.
The p-values for all stats are extremely low (far below 0.05), indicating that there is a statistically significant difference in each stat.

Conclusion:

For every statistic (HP, Attack, Defense, Sp. Atk, Sp. Def, Speed), the p-values are much lower than 0.05, allowing us to reject the null hypothesis for all comparisons.
This confirms the alternative hypothesis (H1) that Legendary Pokémon have different stats compared to Non-Legendary Pokémon. Therefore, this hypothesis is also corroborated by the results.
'''
# Out:
# Comparison of stats between Legendary and Non-Legendary Pokémon:
# HP: t-statistic = 8.036124405043928, p-value = 3.3306476848461913e-15
# Attack: t-statistic = 10.397321023700622, p-value = 7.827253003205333e-24
# Defense: t-statistic = 7.181240122992339, p-value = 1.5842226094427259e-12
# Sp. Atk: t-statistic = 14.191406210846289, p-value = 6.314915770427265e-41
# Sp. Def: t-statistic = 11.03775106120522, p-value = 1.8439809580409597e-26
# Speed: t-statistic = 9.765234331931898, p-value = 2.3540754436898437e-21
# Reject the null hypothesis for the following stats: HP, Attack, Defense, Sp. Atk, Sp. Def, Speed. Legendary Pokémon have different stats compared to Non-Legendary Pokémon.
# '\nInterpretation:\n\nAll the t-statistics are significantly high, indicating a strong difference in means between Legendary and Non-Legendary Pokémon for each stat.\nThe p-values for all stats are extremely low (far below 0.05), indicating that there is a statistically significant difference in each stat.\n\nConclusion:\n\nFor every statistic (HP, Attack, Defense, Sp. Atk, Sp. Def, Speed), the p-values are much lower than 0.05, allowing us to reject the null hypothesis for all comparisons.\nThis confirms the alternative hypothesis (H1) that Legendary Pokémon have different stats compared to Non-Legendary Pokémon. Therefore, this hypothesis is also corroborated by the results.\n'

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 37)
# - Hospital coordinates (-122, 34)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
# Load the data
url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv'
housing_data = pd.read_csv(url)

# Display the data
display(housing_data.head(10))

# Function to calculate Euclidean distance
def calculate_distance(row, school_coords=(-118, 37), hospital_coords=(-122, 34)):
    # Calculate distance to school
    distance_to_school = ((row['longitude'] - school_coords[0])**2 + (row['latitude'] - school_coords[1])**2)**0.5
    # Calculate distance to hospital
    distance_to_hospital = ((row['longitude'] - hospital_coords[0])**2 + (row['latitude'] - hospital_coords[1])**2)**0.5
    return distance_to_school, distance_to_hospital

# Apply the function to calculate distances
housing_data[['distance_to_school', 'distance_to_hospital']] = housing_data.apply(calculate_distance, axis=1, result_type='expand')

# Define the close proximity threshold
threshold = 0.50

# Classify houses based on distance to school or hospital
housing_data['close_to_school_or_hospital'] = ((housing_data['distance_to_school'] < threshold) | 
                                                (housing_data['distance_to_hospital'] < threshold)).astype(int)

# Separate datasets
close_houses = housing_data[housing_data['close_to_school_or_hospital'] == 1]
far_houses = housing_data[housing_data['close_to_school_or_hospital'] == 0]

# Perform the T-Test on median house values
t_statistic, p_value = st.ttest_ind(close_houses['median_house_value'], far_houses['median_house_value'])

print("Comparison of house values between those close to a school or hospital and those that are far:")
print(f"t-statistic = {t_statistic}, p-value = {p_value}")

# Interpret the p-value
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis: Houses close to a school or hospital are more expensive on average.")
else:
    print("Fail to reject the null hypothesis: There is not enough evidence to claim that houses close to a school or hospital are more expensive.")
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# 5       671.0       239.0         3.3438             74000.0
# 6      1841.0       633.0         2.6768             82400.0
# 7       375.0       158.0         1.7083             48500.0
# 8      3134.0      1056.0         2.1782             58400.0
# 9       787.0       271.0         2.1908             48100.0
# Comparison of house values between those close to a school or hospital and those that are far:
# t-statistic = -2.2146147257665834, p-value = 0.026799733071128685
# Reject the null hypothesis: Houses close to a school or hospital are more expensive on average.

# %% [markdown]
# Interpretation:
#
# The t-statistic and p-value obtained from the T-Test help us understand the relationship between house prices and proximity to schools or hospitals. A p-value less than the significance level of 0.05 indicates a statistically significant difference in house prices between the two groups.
#
# Conclusion:
#
# If the p-value is less than 0.05, we reject the null hypothesis, supporting the assertion that houses close to a school or hospital are, on average, more expensive. Conversely, if the p-value is greater than 0.05, we fail to reject the null hypothesis, indicating that proximity to schools or hospitals does not significantly affect house prices.
